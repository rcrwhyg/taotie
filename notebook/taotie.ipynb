# %%
import pandas as pd

# %%
df = pd.read_parquet('../assets/sample.parquet')

# %%
df
# Out:
#                               email name   gender  \
# 0      raphael.b1qn5lcn@example.com  龙水云  unknown
# 1     clifford.6asp6dp6@example.net  宋雪曦  unknown
# 2       destin.d2iywljd@example.net  范曲漾  unknown
# 3        fredy.gc0wauuc@example.net  于凝雁  unknown
# 4      alfonso.jhqvw6dd@example.net  崔婕莲  unknown
# ..                              ...  ...      ...
# 995  marcellus.ndc2gg5x@example.com  夏弘玮  unknown
# 996     julian.pe5mhzxj@example.org  侯睿轩  unknown
# 997    coralie.t8lc0cov@example.net  方冠宇  unknown
# 998      noemi.runi21pz@example.com  孙鼎宇  unknown
# 999     linnea.2lt4hiw0@example.org  高鼎遥  unknown
#
#                           created_at                  last_visited_at  \
# 0   2021-08-11 23:33:03.612415+00:00 2024-09-23 05:50:03.612415+00:00
# 1   2020-07-24 02:52:03.629971+00:00 2024-09-23 03:56:03.629971+00:00
# 2   2024-06-28 18:30:03.643642+00:00 2024-10-18 10:09:03.643643+00:00
# 3   2019-11-07 11:20:03.624421+00:00 2024-10-06 12:02:03.624421+00:00
# ...

# %%
df.head()
# Out:
#                            email name   gender  \
# 0   raphael.b1qn5lcn@example.com  龙水云  unknown
# 1  clifford.6asp6dp6@example.net  宋雪曦  unknown
# 2    destin.d2iywljd@example.net  范曲漾  unknown
# 3     fredy.gc0wauuc@example.net  于凝雁  unknown
# 4   alfonso.jhqvw6dd@example.net  崔婕莲  unknown
#
#                         created_at                  last_visited_at  \
# 0 2021-08-11 23:33:03.612415+00:00 2024-09-23 05:50:03.612415+00:00
# 1 2020-07-24 02:52:03.629971+00:00 2024-09-23 03:56:03.629971+00:00
# 2 2024-06-28 18:30:03.643642+00:00 2024-10-18 10:09:03.643643+00:00
# 3 2019-11-07 11:20:03.624421+00:00 2024-10-06 12:02:03.624421+00:00
# 4 2024-06-28 01:17:03.644586+00:00 2024-10-18 08:14:03.644586+00:00
#
#                    last_watched_at  \
# 0 2024-10-10 21:25:03.612416+00:00
# 1 2024-08-22 05:33:03.629971+00:00
# 2 2024-08-04 16:00:03.643643+00:00
# 3 2024-09-01 03:12:03.624421+00:00
# 4 2024-08-11 16:34:03.644586+00:00
#
# ...

# %%
df.describe()
# Out:
#                               email  name   gender  \
# count                          1000  1000     1000
# unique                         1000   988        1
# top     linnea.2lt4hiw0@example.org   邱芙香  unknown
# freq                              1     2     1000
# mean                            NaN   NaN      NaN
# min                             NaN   NaN      NaN
# 25%                             NaN   NaN      NaN
# 50%                             NaN   NaN      NaN
# 75%                             NaN   NaN      NaN
# max                             NaN   NaN      NaN
#
#                               created_at                   last_visited_at  \
# count                               1000                              1000
# unique                               NaN                               NaN
# top                                  NaN                               NaN
# freq                                 NaN                               NaN
# ...

# %%
df[df['created_at'] > '2024-05-01'] # select * from df where created_at > '2024-05-01'
# Out:
#                                email  name   gender  \
# 2        destin.d2iywljd@example.net   范曲漾  unknown
# 4       alfonso.jhqvw6dd@example.net   崔婕莲  unknown
# 19        janet.fu79ic6a@example.net   苏若菲  unknown
# 60       darren.stnngbrf@example.net   徐月阳  unknown
# 66        laron.9u3k9j4z@example.net   向修永  unknown
# 67      destany.i83j5ljv@example.com   严紫槐  unknown
# 81      herbert.7p5l1evd@example.net   潘雅瑾  unknown
# 155      esther.c7u34k0j@example.net   向秋柔  unknown
# 159        mose.hzluytd9@example.net   蒋琪涵  unknown
# 190     michale.liqfz868@example.org   叶明新  unknown
# 205     monique.jy977kfn@example.net   林彬逸  unknown
# 225      eliane.eattdf27@example.com   于宇驰  unknown
# 249     rowland.zmvsf1lm@example.net   苏碧彤  unknown
# 255     destiny.xofgdjva@example.org   沈世康  unknown
# 263      melany.8603h2uj@example.net   夏宇灿  unknown
# 309      caesar.o5ipyefx@example.com   陶杰书  unknown
# 322      josefa.ky6vbcbd@example.org   袁采菡  unknown
# ...

# %%
df['created_at'].count()
# Out:
# np.int64(1000)
